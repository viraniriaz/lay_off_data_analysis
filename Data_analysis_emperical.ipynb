# %%
import pandas as pd
df = pd.read_csv('layoffs.csv')

# %%
df
# Out:
#                 company        location        industry  total_laid_off  \
# 0     Pear Therapeutics          Boston      Healthcare           170.0
# 1             ZestMoney       Bengaluru         Finance           100.0
# 2     Absolute Software       Vancouver        Security            40.0
# 3              Avocargo          Berlin  Transportation            16.0
# 4                 Dunzo       Bengaluru            Food           300.0
# ...                 ...             ...             ...             ...
# 2468       HopSkipDrive     Los Angeles  Transportation             8.0
# 2469        Panda Squad     SF Bay Area        Consumer             6.0
# 2470      Tamara Mellon     Los Angeles          Retail            20.0
# 2471           EasyPost  Salt Lake City       Logistics            75.0
# 2472          Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# ...

# %%
df.isna().sum()
# Out:
# company                  0
# location                 0
# industry                 2
# total_laid_off         777
# percentage_laid_off    830
# date                     1
# stage                    6
# country                  0
# funds_raised           235
# dtype: int64

# %%
df1=df.dropna()

# %%
df1
# Out:
#                 company       location        industry  total_laid_off  \
# 0     Pear Therapeutics         Boston      Healthcare           170.0
# 1             ZestMoney      Bengaluru         Finance           100.0
# 4                 Dunzo      Bengaluru            Food           300.0
# 5             Amplitude    SF Bay Area            Data            99.0
# 7                 Boost  New York City         Finance            15.0
# ...                 ...            ...             ...             ...
# 2465          Inspirato         Denver          Travel           130.0
# 2466           Help.com         Austin         Support            16.0
# 2468       HopSkipDrive    Los Angeles  Transportation             8.0
# 2469        Panda Squad    SF Bay Area        Consumer             6.0
# 2470      Tamara Mellon    Los Angeles          Retail            20.0
#
#       percentage_laid_off        date     stage        country  funds_raised
# ...

# %%
df1.isna().sum()
# Out:
# company                0
# location               0
# industry               0
# total_laid_off         0
# percentage_laid_off    0
# date                   0
# stage                  0
# country                0
# funds_raised           0
# dtype: int64

# %%
df1.company.unique()
# Out:
# array(['Pear Therapeutics', 'ZestMoney', 'Dunzo', 'Amplitude', 'Boost',
#        'View', 'Textio', 'Domestika', 'Roku', 'FanClash', 'Loop',
#        'Electronic Arts', 'iCAD', 'Lucid Motors', 'AEye', 'Slite',
#        'Indeed', 'Glassdoor', 'Wejo', 'Workhuman', 'FreshBooks',
#        'Smallcase', 'Livspace', 'Symend', 'Course Hero', 'Leafly',
#        'Dukaan', 'Boxed', 'TradeWindow', 'Fetch', 'Anchorage Digital',
#        'Avidbots', 'Kaleidoscope', 'Xero', 'Gopuff', 'Pristyn Care',
#        'Zwift', 'Atlassian', 'SiriusXM', 'Loft', 'Embark Trucks',
#        'Zscaler', 'Fittr', 'CNET', 'Thoughtworks', 'iFood', 'Waymo',
#        'PayFit', 'Sonder', 'Eventbrite', 'Cerebral', 'Amount', 'Palantir',
#        'Outreach', 'Stytch', 'Twitter', 'Ericsson', 'OneFootball',
#        'Green Labs', 'Polygon', 'MyGate', 'Fireblocks', 'Kinde', 'Micron',
#        'Chipper Cash', 'DocuSign', 'Pico Interactive', 'The RealReal',
#        'Smartsheet', 'Wix', 'ServiceTitan', 'Neon', 'DigitalOcean',
# ...
